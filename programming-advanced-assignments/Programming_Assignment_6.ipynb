# %% [markdown]
# ### 1. You are given two strings s and t. String t is generated by randomly shuffling string s and then adding one more letter at a random position. Return the letter that was added to t.
#     Examples:
#     find_the_difference("abcd", "abcde") ➞ "e"
#     find_the_difference("", "y") ➞ "y"
#     find_the_difference("ae", "aea") ➞ "a"

# %%
def find_the_difference(s, t):
    sum_of_s = 0
    sum_of_t = 0
    for i in range(len(s)):
        sum_of_s = sum_of_s + (ord(s[i]))
    for j in range(len(t)):
        sum_of_t = sum_of_t + ord(t[j])
    difference = abs(sum_of_s -sum_of_t)
    return chr(difference)

# %%
find_the_difference("abcd", "abcde")
# Out:
# 'e'

# %%
find_the_difference("", "y")
# Out:
# 'y'

# %%
find_the_difference("ae", "aea")
# Out:
# 'a'

# %% [markdown]
# ### 2. Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. Finally return the total in a list.
#     List order is: [int, str, bool, list, tuple, dictionary]
#     Examples:
#     count_datatypes(1, 45, "Hi", False) ➞ [2, 1, 1, 0, 0, 0]
#     count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1) ➞ [3, 0, 0, 1, 1, 0]
#     count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1,
#     3], {"Brayan": 18}, 25, 23) ➞ [2, 2, 3, 1, 0, 2]
#     count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6]) ➞ [2,
#     0, 1, 2, 2, 0]

# %%
def count_datatypes(*args):
    count_list = [0, 0, 0, 0, 0, 0]
    for i in args:
        if type(i) == int:
            count_list[0] += 1
        elif type(i) == str:
            count_list[1] += 1
        elif type(i) == bool:
            count_list[2] += 1
        elif type(i) == list:
            count_list[3] += 1
        elif type(i) == tuple:
            count_list[4] += 1
        elif type(i) == dict:
            count_list[5] += 1
    return count_list

# %%
count_datatypes(1, 45, "Hi", False)
# Out:
# [2, 1, 1, 0, 0, 0]

# %%
count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)
# Out:
# [3, 0, 0, 1, 1, 0]

# %%
count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1,3], {"Brayan": 18}, 25, 23)
# Out:
# [2, 2, 3, 1, 0, 2]

# %%
count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])
# Out:
# [2, 0, 1, 2, 2, 0]

# %% [markdown]
# ### 3. A Fibonacci string is a precedence of the Fibonacci series. It works with any two characters of the English alphabet (as opposed to the numbers 0 and 1 in the Fibonacci series) as the initial items and concatenates them together as it progresses in a similar fashion as the Fibonacci series.
#     Examples:
#     fib_str(3, ["j", "h"]) ➞ "j, h, hj"
#     fib_str(5, ["e", "a"]) ➞ "e, a, ae, aea, aeaae"
#     fib_str(6, ["n", "k"]) ➞ "n, k, kn, knk, knkkn, knkknknk"

# %%
def fib_str(num, lst):
    num = num-1
    a, b = lst[0], lst[1]
    fibonacci_list = []
    if num <= 0:
        return ""
    elif num == 1:
        return a
    else:
        count = 0
        while count <= num:   
            fibonacci_list.append(a)
            count += 1
            if count > num:
                return ", ".join(fibonacci_list)
            temp = a + b
            a, b = b, temp

# %%
fib_str(3, ["j", "h"])
# Out:
# 'j, h, jh'

# %%
fib_str(5, ["e", "a"])
# Out:
# 'e, a, ea, aea, eaaea'

# %%
fib_str(6, ["n", "k"])
# Out:
# 'n, k, nk, knk, nkknk, knknkknk'

# %% [markdown]
# ### 4. Given an integer between 0 and 26, make a variable (self.answer). That variable would be assigned to a string in this format: "nines:your answer, threes:your answer, ones:your answer"
#     You need to find out how many ones, threes, and nines it would at least take for the number of each to add up to the given integer when multiplied by one, three or nine (depends).
#     Examples:
#     ones_threes_nines(10) ➞ "nines:1, threes:0, ones:1"
#     ones_threes_nines(15) ➞ "nines:1, threes:2, ones:0"
#     ones_threes_nines(22) ➞ "nines:2, threes:1, ones:1"

# %%
def ones_threes_nines(num):
    results = {'nines': 0, 'threes': 0, 'ones': 0}
    strings = ''
    while(num > 0):
        if num // 9 > 0:
            results['nines'] = num // 9
            num = num % 9
        elif num // 3 > 0:
            results['threes'] = num // 3
            num = num % 3
        else:
            results['ones'] = num // 1
            num = num % 1
        
    for key,value in results.items():
        strings = strings + key + ':' + str(value) + ' '
    return ', '.join(strings.strip().split())

# %%
ones_threes_nines(10)
# Out:
# 'nines:1, threes:0, ones:1'

# %%
ones_threes_nines(15)
# Out:
# 'nines:1, threes:2, ones:0'

# %%
ones_threes_nines(22)
# Out:
# 'nines:2, threes:1, ones:1'

# %% [markdown]
# ### 5. The Fibonacci sequence is a classic use case for recursive functions since the value of the sequence at a given index is dependent on the sum of the last two values. However, the recursion tree created by solving the Fibonacci sequence recursively can grow quite fast. Therefore it can be important to think about the implications of running a function recursively. Depending on the size of n needed and the capabilities of the system in question you might want to take a different approach.
#     Write a non-recursive function that takes an integer n and returns the
#     Fibonacci sequence's value at index n.
#     Examples:
#     fib(6) ➞ 8
#     # 0 + 1 = 1, 1 + 1 = 2, 1 + 2 = 3, 2 + 3 = 5, 3 + 5 = 8
#     fib(1) ➞ 1
#     fib(2) ➞ 1

# %%
def fib(terms):
    n1, n2 = 0, 1
    count = 0
    lst = []
    if terms <= 0:
        print(0)
    elif terms == 1:
        return 1
    else:
        while count < terms:
            lst.append(n1)
            nth = n1 + n2
            n1 = n2
            n2 = nth
            count += 1
        
        length = len(lst)
        if (length > 1):
            return lst[length-2] + lst[length-1]

# %%
fib(6)
# Out:
# 8

# %%
fib(1)
# Out:
# 1

# %%
fib(2)
# Out:
# 1
